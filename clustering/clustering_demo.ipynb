# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import style
style.use("ggplot")

from sklearn.cluster import KMeans

from PIL import Image

# %%
X = np.array([[1,2],[5,8],[6,9],[4,10],[1.5,1.8],[8,10],[1,0.6],[4,8],[9,11]])

# %%
for i in range(len(X)):
   plt.plot(X[i][0],X[i][1],"g.",markersize=10)

plt.show()

# %%
kmeans = KMeans(n_clusters=3)
kmeans.fit(X)

centroid = kmeans.cluster_centers_
labels = kmeans.labels_

# %%
print (centroid)
print(labels)
# Out:
# [[  1.16666667   1.46666667]
#  [  4.75         8.75      ]
#  [  8.5         10.5       ]]
# [0 1 1 1 0 2 0 1 2]

# %%
colors = ["g.","r.","c."]

for i in range(len(X)):
   print ("coordinate:" , X[i], "label:", labels[i])
   plt.plot(X[i][0],X[i][1],colors[labels[i]],markersize=10)

plt.scatter(centroid[:,0],centroid[:,1], marker = "x", s=150, linewidths = 5, zorder =10)

plt.show()
# Out:
# ('coordinate:', array([ 1.,  2.]), 'label:', 0)
# ('coordinate:', array([ 5.,  8.]), 'label:', 1)
# ('coordinate:', array([ 6.,  9.]), 'label:', 1)
# ('coordinate:', array([  4.,  10.]), 'label:', 1)
# ('coordinate:', array([ 1.5,  1.8]), 'label:', 0)
# ('coordinate:', array([  8.,  10.]), 'label:', 2)
# ('coordinate:', array([ 1. ,  0.6]), 'label:', 0)
# ('coordinate:', array([ 4.,  8.]), 'label:', 1)
# ('coordinate:', array([  9.,  11.]), 'label:', 2)

# %%
fname='img/elephant.jpg'
#fname='img/face.jpg'

im=Image.open(fname).resize((224, 224), Image.ANTIALIAS)

# %%
# Plot it
im = np.array(im)

plt.figure(figsize=(6, 6))
plt.axis("off")
plt.imshow(im)
plt.show()

# %%
im.shape
# Out:
# (224, 224, 3)

# %%
im2=im.reshape(224*224,3)

# %%
kmeans = KMeans(n_clusters=4)
kmeans.fit(im2)

centroid = kmeans.cluster_centers_
labels = kmeans.labels_

# %%
centroid.shape
# Out:
# (4, 3)

# %%
labels.shape
# Out:
# (50176,)

# %%
im3=labels.reshape(224,224)

# %%
plt.figure(figsize=(6, 6))
plt.axis("off")
plt.imshow(im3)
plt.colorbar()
plt.show()

# %%
im4=np.zeros([50176,3])

# %%
iter=-1
for label in labels:
    iter=iter+1
    im4[iter,:]=centroid[label,:]

# %%
im5=im4.reshape(224,224,3)

# %%
plt.figure(figsize=(6, 6))
plt.axis("off")
plt.imshow(im5/256)
plt.show()
